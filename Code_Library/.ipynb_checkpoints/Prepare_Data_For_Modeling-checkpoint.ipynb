# %% [markdown]
# # Preparing the Data for Modeling

# %% [markdown]
# #### Start by importing necessary packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %% [markdown]
# #### Import the cleaned data.
#
# This is the same data that is explored in the EDA file.

# %%
# Import the cleaned data
df = pd.read_csv('../Data/Cleaned_Data_03212024.csv')

# %%
# Set the max columns to infinite so that we may view all of them
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Handling Null Values

# %% [markdown]
# #### We show and remove null values for modeling purposes.
#
# We remove the rows with null values for square feet and ones that do not have an address listed.
#
# The ones without addresses listed contain the string "None listed." However, the null values show up in the location coordinates. When we remove the missing address ones, the null values in these rows (latitude, longitude, nearest_budget_grocery_store_distance, etc.) will reduce to none.

# %%
# Show which features contain null values
df.isna().sum()
# Out:
# title                                       0
# price                                       0
# Bedrooms                                    0
# square_feet                               217
# full_address                                0
# monthly                                     0
# apartment                                   0
# cats_allowed                                0
# dogs_allowed                                0
# laundry_on_site                             0
# air_conditioning                            0
# off_street_parking                          0
# EV_charging                                 0
# washer_dryer_in_unit                        0
# no_smoking                                  0
# carport                                     0
# attached_garage                             0
# detached_garage                             0
# laundry_in_bldg                             0
# fee_needed_to_apply                         0
# wheelchair_accessible                       0
# no_parking                                  0
# furnished                                   0
# street_parking                              0
# no_laundry_on_site                          0
# house                                       0
# washer_dryer_hookups                        0
# latitude                                  392
# longitude                                 392
# nearest_budget_grocery_store_distance     392
# nearest_budget_grocery_store              392
# nearest_midTier_grocery_store_distance    392
# nearest_midTier_grocery_store             392
# nearest_premium_grocery_store_distance    392
# nearest_premium_grocery_store             392
# dtype: int64

# %%
# Drop the rows with null square_feet measures
df.dropna(subset=['square_feet'], inplace=True)

# %%
# Create a copy of the DataFrame with the missing address rows filtered out
filtered_listings_df = df[df['full_address'] != 'None listed'].copy()

# %%
# Check to see that there are no null values now
filtered_listings_df.isnull().sum()
# Out:
# title                                     0
# price                                     0
# Bedrooms                                  0
# square_feet                               0
# full_address                              0
# monthly                                   0
# apartment                                 0
# cats_allowed                              0
# dogs_allowed                              0
# laundry_on_site                           0
# air_conditioning                          0
# off_street_parking                        0
# EV_charging                               0
# washer_dryer_in_unit                      0
# no_smoking                                0
# carport                                   0
# attached_garage                           0
# detached_garage                           0
# laundry_in_bldg                           0
# fee_needed_to_apply                       0
# wheelchair_accessible                     0
# no_parking                                0
# furnished                                 0
# street_parking                            0
# no_laundry_on_site                        0
# house                                     0
# washer_dryer_hookups                      0
# latitude                                  0
# longitude                                 0
# nearest_budget_grocery_store_distance     0
# nearest_budget_grocery_store              0
# nearest_midTier_grocery_store_distance    0
# nearest_midTier_grocery_store             0
# nearest_premium_grocery_store_distance    0
# nearest_premium_grocery_store             0
# dtype: int64

# %% [markdown]
# ## Standardization

# %% [markdown]
# #### Let us now use StandardScaler from sklearn to standardize a few features.
#
# We have chosen to standardize and not normalize this data. Standardization will transform the features we want such that the mean will be zero with a standard deviation of one. These features include square_feet, nearest_budget_grocery_store_distance, nearest_midTier_grocery_store_distance, and nearest_premium_grocery_store_distance.
#
# We do not need to worry about the boolean features or the latitudes and longitudes. Standardization is chosen over normalization because the range varies widely in each of the four features.

# %%
# Initialize the StandardScaler
scaler = StandardScaler()

# %%
# Select columns to standardize
columns_to_standardize = ['square_feet', 'nearest_budget_grocery_store_distance', 
                          'nearest_midTier_grocery_store_distance', 'nearest_premium_grocery_store_distance']

# %%
# Standardize the selected columns
filtered_listings_df[columns_to_standardize] = scaler.fit_transform(filtered_listings_df[columns_to_standardize])

# %%
target = filtered_listings_df['price']

# %%
target
# Out:
# 0       3295
# 2       2700
# 3       2895
# 4       3438
# 6       2895
#         ...
# 1910    3095
# 1911    2471
# 1912    3275
# 1914    1895
# 1915    2895
# Name: price, Length: 1352, dtype: int64

# %%
# Create the features by dropping unwanted variables
features = filtered_listings_df.drop(['title', 'nearest_budget_grocery_store', 
                    'nearest_midTier_grocery_store', 'house', 'monthly', 'latitude', 
                    'nearest_premium_grocery_store', 'Bedrooms', 'fee_needed_to_apply',
                    'full_address', 'apartment', 'price', 'longitude'], axis=1)

# %%
features.head()
# Out:
#    square_feet  cats_allowed  dogs_allowed  laundry_on_site  air_conditioning  \
# 0     0.686600             1             0                1                 1
# 2    -0.280796             1             1                1                 0
# 3     0.686600             0             0                0                 0
# 4     0.450797             1             1                0                 1
# 6    -0.371490             0             0                1                 0
#
#    off_street_parking  EV_charging  washer_dryer_in_unit  no_smoking  carport  \
# 0                   1            0                     0           0        0
# 2                   0            0                     0           0        1
# 3                   1            0                     0           0        0
# 4                   0            0                     1           0        0
# 6                   1            0                     0           1        0
#
#    attached_garage  detached_garage  laundry_in_bldg  wheelchair_accessible  \
# 0                0                0                0                      0
# 2                0                0                0                      0
# 3                0                0                1                      0
# 4                0                1                0                      0
# 6                0                0                0                      0
#
#    no_parking  furnished  street_parking  no_laundry_on_site  \
# 0           0          0               0                   0
# 2           0          0               0                   0
# 3           0          0               0                   0
# 4           0          0               0                   0
# 6           0          0               0                   0
#
#    washer_dryer_hookups  nearest_budget_grocery_store_distance  \
# 0                     0                              -0.280580
# 2                     0                              -0.806110
# 3                     0                              -1.071798
# 4                     0                              -0.927067
# 6                     0                              -0.590988
#
#    nearest_midTier_grocery_store_distance  \
# 0                                0.760061
# 2                                0.101309
# 3                                0.189256
# 4                               -0.866914
# 6                                0.469901
#
#    nearest_premium_grocery_store_distance
# 0                               -0.734804
# 2                               -0.275459
# 3                               -1.025081
# 4                               -0.331386
# 6                               -0.809671

# %% [markdown]
# #### Let's now perform splitting of the data for the model.

# %%
# Split the features and target variable into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %% [markdown]
# ## Linear Regression

# %%
# Linear Regression
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Retrieve the coefficients
coefficients = linear_model.coef_

# Pair each feature with its coefficient
feature_coefficients = pd.DataFrame(data=coefficients, index=X_train.columns, columns=['Coefficient'])

# Round off the values
feature_coefficients = feature_coefficients.apply(lambda x: round(x, 2))

# Display the coefficients
print(feature_coefficients)
# Out:
#                                         Coefficient
# square_feet                                  168.56
# cats_allowed                                  98.36
# dogs_allowed                                 217.19
# laundry_on_site                              -80.34
# air_conditioning                             -44.27
# off_street_parking                          -209.40
# EV_charging                                  203.06
# washer_dryer_in_unit                         384.41
# no_smoking                                    21.00
# carport                                     -340.48
# attached_garage                             -402.89
# detached_garage                             -475.66
# laundry_in_bldg                              -91.11
# wheelchair_accessible                        648.87
# no_parking                                    59.00
# furnished                                   -498.93
# street_parking                              -489.82
# no_laundry_on_site                            81.58
# washer_dryer_hookups                        -294.55
# nearest_budget_grocery_store_distance         79.19
# nearest_midTier_grocery_store_distance         0.10
# nearest_premium_grocery_store_distance      -170.36

# %%
predictions = linear_model.predict(X_test)
residuals = y_test - predictions

plt.figure(figsize=(10, 6))
sns.scatterplot(x=predictions, y=residuals)
plt.axhline(y=0, color='red', linestyle='--')
plt.title('Residuals vs. Predicted Values')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.show()

# %%
coefficients = pd.DataFrame(data=linear_model.coef_, index=X_train.columns, columns=['Coefficient'])
coefficients.sort_values(by='Coefficient', ascending=False, inplace=True)

plt.figure(figsize=(10, 8))
sns.barplot(x=coefficients['Coefficient'], y=coefficients.index)
plt.title('Importance of Features')
plt.xlabel('Coefficient Magnitude')
plt.ylabel('Features')
plt.show()

# %%
sns.histplot(residuals, bins=30, kde=True)
plt.title('Distribution of Residuals')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.show()

# %%
# Linear Regression Predictions
y_pred_linear = linear_model.predict(X_test)

# %%
mae_linear = mean_absolute_error(y_test, y_pred_linear)
mse_linear = mean_squared_error(y_test, y_pred_linear)
rmse_linear = np.sqrt(mse_linear)
r2_linear = r2_score(y_test, y_pred_linear)

print(f"Mean Absolute Error (MAE): {mae_linear}")
print(f"Mean Squared Error (MSE): {mse_linear}")
print(f"Root Mean Squared Error (RMSE): {rmse_linear}")
print(f"R-squared (R²) score: {r2_linear}")
# Out:
# Mean Absolute Error (MAE): 267.2242095149593
# Mean Squared Error (MSE): 193509.74624671985
# Root Mean Squared Error (RMSE): 439.89742696078577
# R-squared (R²) score: 0.4569644262677762

# %% [markdown]
# ## Random Forest

# %%
# Random Forest Regression
random_forest_model = RandomForestRegressor(
    n_estimators=100, 
    random_state=42)
random_forest_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# ## Gradient Boosting

# %%
# Gradient Boosting Regression
gradient_boosting_model = GradientBoostingRegressor(
    n_estimators=100, 
    learning_rate=0.1, 
    max_depth=3, 
    random_state=42)
gradient_boosting_model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=42)
